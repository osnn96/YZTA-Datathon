# %% [markdown]
# ### Veri Kümesi Açıklaması
#
# - **train.csv**: Eğitim seti
# - **testFeatures.csv**: Test seti - Fiyatların tahmin edilebileceği dosya
# - **sample_submission.csv**: Örnek dosya yükleme formatı (testFeatures dosyasındaki tüm ID'ler için tahminler yapılmalıdır)
#
# ### Veri Setindeki Sütunlar
#
# - **tarih**: Ürünün değiştirildiği tarih
# - **ürün**: Ürünün ismi
# - **ürün besin değeri**: Ürünün sahip olduğu besin değeri
# - **ürün kategorisi**: Ürünün ait olduğu kategori
# - **ürün fiyatı**: Ürünün fiyatı
# - **ürün üretim yeri**: Ürünün satış yeri
# - **market**: Ürünün satıldığı pazar
# - **şehir**: Ürünün satıldığı şehir
#
# Bu yarışmanın amacı, **test setindeki ürünlerin satış fiyatlarını tahmin etmek**. Test setindeki her bir ürünün fiyatını doğru şekilde tahmin etmemiz gerekmektedir.

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
df = pd.read_csv("train.csv")
test=pd.read_csv("testFeatures.csv")
df.head(10)
# Out:
#         tarih           ürün  ürün besin değeri    ürün kategorisi  \
# 0  2019-01-01          kıyma                120                 et
# 1  2019-01-01          tavuk                103                 et
# 2  2019-01-01          hindi                160                 et
# 3  2019-01-01     Bakla-kuru                354  sebze ve bakliyat
# 4  2019-01-01     Bakla-taze                 72  sebze ve bakliyat
# 5  2019-01-01          Bamya                 42  sebze ve bakliyat
# 6  2019-01-01  Barbunya-kuru                346  sebze ve bakliyat
# 7  2019-01-01   Bezelye-taze                 47  sebze ve bakliyat
# 8  2019-01-01    Biber-yeşil                 25  sebze ve bakliyat
# 9  2019-01-01  Brüksel laha.                 47  sebze ve bakliyat
#
#    ürün fiyatı ürün üretim yeri market şehir
# 0        32.70         Yurt içi      K     S
# 1        11.04         Yurt içi      K     S
# 2        11.20         Yurt içi      K     S
# 3         7.04         Yurt içi      K     S
# ...

# %%
df.tail(10)
# Out:
#              tarih      ürün  ürün besin değeri ürün kategorisi  ürün fiyatı  \
# 227510  2023-12-01       Nar                 77           meyve        38.35
# 227511  2023-12-01  Portakal                 41           meyve        15.99
# 227512  2023-12-01   Şeftali                 49           meyve        21.58
# 227513  2023-12-01      Üzüm                 74           meyve        21.56
# 227514  2023-12-01     Vişne                 57           meyve        17.12
# 227515  2023-12-01    fındık                110       kuruyemiş        57.51
# 227516  2023-12-01    fıstık                115       kuruyemiş        70.25
# 227517  2023-12-01      kaju                100       kuruyemiş        70.21
# 227518  2023-12-01     badem                110       kuruyemiş        62.87
# 227519  2023-12-01     ceviz                120       kuruyemiş        78.72
#
#        ürün üretim yeri market şehir
# 227510        Yurt dışı      Y     H
# 227511        Yurt dışı      Y     H
# ...

# %%
df.shape
# Out:
# (227520, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227520 entries, 0 to 227519
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tarih              227520 non-null  object
#  1   ürün               227520 non-null  object
#  2   ürün besin değeri  227520 non-null  int64
#  3   ürün kategorisi    227520 non-null  object
#  4   ürün fiyatı        227520 non-null  float64
#  5   ürün üretim yeri   227520 non-null  object
#  6   market             227520 non-null  object
#  7   şehir              227520 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 13.9+ MB

# %% [markdown]
# #### 🔼Veri Tipleri:
#
# - **int64**: Sadece bir sütunda, "ürün besin değeri" sütununda bulunuyor.
# - **float64**: Sadece "ürün fiyatı" sütununda bulunuyor.
# - **object**: Diğer tüm sütunlar, yani kategorik veriler string formatında saklanıyor.
#
# #### Eksik Değerler:
# - Tüm sütunlar **non-null** (eksik veri yok), yani her satırda bir değer bulunuyor.

# %%
df.describe()
# Out:
#        ürün besin değeri    ürün fiyatı
# count      227520.000000  227520.000000
# mean          143.113924      17.018837
# std           133.218871      14.470524
# min             8.000000       0.740000
# 25%            41.000000       7.380000
# 50%            83.000000      12.860000
# 75%           250.000000      21.630000
# max           402.000000     164.530000

# %% [markdown]
# #### 🔼**Ürün Fiyatı**
# - **Mean (Ortalama)**: 17.02 (Ürünlerin ortalama fiyatı 17.02).
# - **Std (Standart Sapma)**: 14.47 (Fiyatlar da oldukça değişken, geniş bir aralıkta dağılmış).
# - **Min (Minimum)**: 0.74 (En düşük fiyat 0.74).
# - **Max (Maksimum)**: 164.53 (En yüksek fiyat 164.53).
#
# Ürün fiyatları arasında da büyük bir değişkenlik bulunuyor. Ortalama fiyat 17.02 olmakla birlikte, fiyatlar 0.74 ile 164.53 arasında değişiyor. Fiyatların çeyrek dilimleri arasındaki fark da (7.38 ile 21.63) geniş bir yayılım olduğunu ve bazı ürünlerin çok daha pahalı olabileceğini gösteriyor. Bu da fiyatların heterojen bir dağılıma sahip olduğunu ortaya koyuyor.
#
# Her iki değişken de (besin değeri ve fiyat) oldukça geniş bir dağılıma sahip. Bu durum, ürünlerin çeşitliliğinin yüksek olduğunu ve bazı ürünlerin belirgin şekilde daha pahalı ve besin değeri açısından daha zengin olabileceğini gösteriyor.

# %%
df['ürün'].nunique()
# Out:
# 79

# %%
df['ürün'].unique()
# Out:
# array(['kıyma', 'tavuk', 'hindi', 'Bakla-kuru', 'Bakla-taze', 'Bamya',
#        'Barbunya-kuru', 'Bezelye-taze', 'Biber-yeşil', 'Brüksel laha.',
#        'Domates', 'Enginar', 'Fasulye-kuru', 'Fasulye-taze', 'Havuç',
#        'Salatalık', 'Ispanak', 'Kabak', 'Karnabahar', 'Kereviz-baş',
#        'Kırmızı-pancar', 'Lahana', 'Mantar', 'Marul', 'Mercimek-kuru',
#        'Nohut', 'Pancar', 'Patates', 'Patlıcan', 'Pazı', 'Pırasa',
#        'Semizotu', 'Buğday ekmeği', 'Bulgur', 'Erişte', 'Makarna',
#        'Mısır', 'Mısır unu', 'Nişasta', 'Pilav', 'Pirinç unu', 'Şehriye',
#        'Tarhana', 'Yulaf unu', 'yumurta', 'beyaz peynir', 'Kaşar peyniri',
#        'krema', 'yoğurt', 'sucuk', 'salam', 'sosis', 'tam buğday ekmek',
#        'kaymak', 'bal', 'tereyağ', 'Armut', 'Çilek', 'Elma',
#        'Erik türleri', 'İncir', 'Karadut', 'Karpuz', 'Kavun', 'Kayısı',
#        'Kiraz', 'Limon', 'Mandalina', 'Muz', 'Nar', 'Portakal', 'Şeftali',
# ...

# %%
df['ürün kategorisi'].nunique()
# Out:
# 6

# %%
df['ürün kategorisi'].unique()
# Out:
# array(['et', 'sebze ve bakliyat', 'tahıl ve ürünleri',
#        'süt ürünleri ve kahvaltılık', 'meyve', 'kuruyemiş'], dtype=object)

# %%
df['ürün kategorisi'].value_counts()
df['ürün kategorisi'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='ürün kategorisi'>

# %% [markdown]
# #### 🔼Ürün Kategorilerine Göre Dağılım
#
# Veri kümesinde yer alan ürünler, farklı kategorilere ayrıldığında:
#
# - **En Çok Ürüne Sahip Kategori**: **Sebze ve Bakliyat**
#   - Sebzeler ve bakliyatlar, listede en fazla ürüne sahip kategori olarak öne çıkıyor.
#
# - **En Az Ürüne Sahip Kategori**: **Et**
#   - Et kategorisi, diğer kategorilere kıyasla çok daha az ürüne sahip.

# %%
df['ürün üretim yeri'].value_counts()
df["ürün üretim yeri"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='ürün üretim yeri'>

# %% [markdown]
# #### 🔼Ürün Üretim Yerine Göre Dağılım
#
# Görüldüğü üzere **"Yurt içi"** ve **"Yurt dışı"** üretimli ürünler neredeyse eşit sayılardadır.
# Bu durum, veri setinde **hem yerli hem de ithal ürünlerin dengeli bir şekilde temsil edildiğini** göstermektedir.

# %%
df['şehir'].unique()
df["şehir"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='şehir'>

# %% [markdown]
# #### 🔼Şehire Göre Dağılım
#
# 8 farklı şehir bulunmakta ve her birinde eşit sayıda veri girişi sağlanmıştır.

# %%
df['market'].unique()
df["market"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='market'>

# %% [markdown]
# #### 🔼Markete Göre Dağılım
#
# 3 farklı market bulunmakta ve her birinde eşit sayıda veri girişi sağlanmıştır.

# %%
sns.violinplot(x=df['ürün fiyatı'], y=df['ürün kategorisi'])
# Out:
# <Axes: xlabel='ürün fiyatı', ylabel='ürün kategorisi'>

# %% [markdown]
# #### 🔼Ürün Kategorilerine Göre Fiyat Dağılımı
#
# Yukarıdaki violin plot, her bir ürün kategorisindeki ürünlerin fiyat dağılımını göstermektedir. Örneğin, et kategorisinde ürün fiyatları daha geniş bir aralığa yayılmış ve fiyatlar 0'dan 175'e kadar çıkmaktadır. Diğer kategorilerde (örneğin kuruyemiş veya sebze-bakliyat) fiyatlar daha dar bir aralıkta yoğunlaşmıştır.

# %%
plt.figure(figsize=(14,6))
sns.lineplot(x='tarih', y='ürün fiyatı', data=df.sort_values('tarih'))

plt.xticks(rotation=90)  # Tarihleri 90 derece döndür
plt.xlabel("Tarih")
plt.ylabel("Ürün Fiyatı")
plt.title("Zaman İçinde Ürün Fiyatlarının Değişimi", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 🔼Ürün Fiyatlarının Yıllara Göre Değişimi
#
# **Sürekli Artan Bir Trend Var:** Ürün fiyatları yıllar içinde istikrarlı bir şekilde artış göstermektedir. Özellikle 2022 sonrası bu artış daha da hızlanmıştır.
#
# **2022 Sonrası Hızlı Yükseliş:** Grafiğin eğimi 2022 yılından itibaren daha da dikleşiyor. Bu, o dönemden itibaren fiyat artışlarının hızlandığını gösteriyor. Ekonomik koşullar, enflasyon veya üretim maliyetlerindeki artış gibi nedenler buna sebep olabilir.
#
# **Mevsimsel Dalgalanma Yok:** Grafikte belirgin bir mevsimsel iniş-çıkış görülmüyor. Bu da ürün fiyatlarının ağırlıklı olarak trend bileşeniyle (uzun vadeli artış) değiştiğini gösteriyor.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Her ürün için benzersiz besin değerlerini topla
besin_df = df.groupby("ürün")["ürün besin değeri"].unique().reset_index()
besin_df.columns = ["ürün", "besin_değeri_listesi"]

# Her ürünün birden fazla farklı besin değeri olup olmadığını kontrol et
besin_df['besin_değeri_durumu'] = besin_df['besin_değeri_listesi'].apply(
    lambda x: "Birden fazla" if len(x) > 1 else "Tek değer"
)

# Durumlara göre sayıları hesapla
deger_sayilari = besin_df['besin_değeri_durumu'].value_counts()

# Grafik oluştur
plt.figure(figsize=(6, 4))
deger_sayilari.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title("Ürünlerin Besin Değeri Farklılık Durumu")
plt.ylabel("Ürün Sayısı")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 🔼 Ürünlerin Besin Değeri Farklılık Durumu
#
# Grafikten anlaşıldığı gibi her bir ürünün besin değeri değişmiyor.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.scatter(df["ürün besin değeri"], df["ürün fiyatı"], alpha=0.5)
plt.xlabel("Besin Değeri")
plt.ylabel("Fiyat")
plt.title("Besin Değeri ile Fiyat Arasındaki İlişki")
plt.grid(True)
plt.show()

# %%
df[["ürün besin değeri", "ürün fiyatı"]].corr()
# Out:
#                    ürün besin değeri  ürün fiyatı
# ürün besin değeri           1.000000     0.016097
# ürün fiyatı                 0.016097     1.000000

# %% [markdown]
# #### 🔼Besin Değeri ile Fiyat Arasındaki İlişki
#
# Yukarıdaki korelasyon bilgisinden anlaşılıyor ki ürün fiyatı ile besin değeri arasında sıfıra çok yakın bir korelasyon var. Bu demek oluyor ki: Ürün besin değeri ile ürün fiyatı arasında neredeyse hiç ilişki yok. Yani fiyatlandırma besin değerinden ziyade farklı unsurlar tarafından etkilenmektedir.

# %%
df.groupby("ürün üretim yeri")["ürün fiyatı"].mean()
# Out:
# ürün üretim yeri
# Yurt dışı    17.023561
# Yurt içi     17.014113
# Name: ürün fiyatı, dtype: float64

# %%
df.groupby("ürün üretim yeri")["ürün fiyatı"].mean().plot(kind='bar', color='skyblue')
plt.ylabel("Ortalama Fiyat")
plt.title("Üretim Yerine Göre Ortalama Ürün Fiyatı")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
from scipy.stats import ttest_ind

yurt_ici = df[df["ürün üretim yeri"] == "Yurt içi"]["ürün fiyatı"]
yurt_disi = df[df["ürün üretim yeri"] == "Yurt dışı"]["ürün fiyatı"]

t_stat, p_value = ttest_ind(yurt_ici, yurt_disi, equal_var=False)

print("t-istatistiği:", t_stat)
print("p-değeri:", p_value)
# Out:
# t-istatistiği: -0.1557288337777906
# p-değeri: 0.8762469065329702

# %% [markdown]
# #### 🔼Üretim Yerine Göre Ortalama Ürün Fiyatı
#
# p-değerinin 0.05'ten büyük olması anlamlı bir farkın yokluğunu işaret ediyor. Yani üretim yeri fiyatı anlamlı bir şekilde etkilemiyor.

# %% [markdown]
# EDA(Exploratory Data Analysis) kısmı sonrası model eğitimi aşaması
#
# Modeli eğitmeden önce belirli bir ürün ile seçilen modelin doğruluğunun tespiti
#
# Son kod bloğunda ise, seçilen model ile testFeatures.csv dosyasındaki her ürünün fiyat tahmininin submission.csv dosyasında depolanması

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# Uyarıları bastır
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# 1. Veriyi yükle ve filtrele
df = pd.read_csv("train.csv", parse_dates=["tarih"])
df["new_id"] = df["ürün"] + "_" + df["ürün üretim yeri"] + "_" + df["market"] + "_" + df["şehir"]
target_id = "kıyma_Yurt içi_K_S"
ts = df[df["new_id"] == target_id].set_index("tarih")["ürün fiyatı"].sort_index()

# 2. Eğitim / validasyon ayrımı: 2019-2022 eğitim, 2023 validasyon
# (1) Zaman serilerine frekans atama
train_ts = ts.asfreq('MS')
val_ts   = ts.asfreq('MS')


# (2) Daha basit bir seasonal_order deneyin
sarimax_model = SARIMAX(
    train_ts,
    order=(1,0,10),
    seasonal_order=(0,0,1,12),   # Yıllık mevsimsellik: fark+MA
    enforce_stationarity=False,
    enforce_invertibility=False
)


res = sarimax_model.fit(disp=False)

# 4. 2023 tahmini
pred = res.predict(start=val_ts.index[0], end=val_ts.index[-1])

# 5. Değerlendirme
rmse  = np.sqrt(mean_squared_error(val_ts, pred))
mae   = mean_absolute_error(val_ts, pred)
print(f"SARIMAX Validation RMSE (2023): {rmse:.2f} TL")
print(f"SARIMAX Validation MAE  (2023): {mae:.2f} TL")

# 6. Grafik
plt.figure(figsize=(8,4))
plt.plot(train_ts.index, train_ts, label="Train Fiyat")
plt.plot(val_ts.index, val_ts, label="Gerçek 2023 Fiyat")
plt.plot(pred.index, pred, linestyle="--", label="SARIMAX Tahmin")
plt.xlabel("Tarih")
plt.ylabel("Ürün Fiyatı")
plt.title(f"{target_id} Fiyat Tahmini (SARIMAX)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# SARIMAX Validation RMSE (2023): 4.33 TL
# SARIMAX Validation MAE  (2023): 1.31 TL

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# uyarıları bastır
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# 1. Veriyi yükle
train = pd.read_csv("train.csv", parse_dates=["tarih"])
test  = pd.read_csv("testFeatures.csv", parse_dates=["tarih"])

# 2. new_id sütununu hem train hem test için oluştur
for df in (train, test):
    df["new_id"] = (
        df["ürün"] + "_" +
        df["ürün üretim yeri"] + "_" +
        df["market"] + "_" +
        df["şehir"]
    )

# 3. Tahminleri toplamak için bir liste
predictions = []

# 4. Her bir unique new_id grubunu sırayla ele al
for uid, grp in test.groupby("new_id"):
    # a) Geçmiş zaman serisini hazırla
    ts = (train[train["new_id"] == uid]
          .set_index("tarih")["ürün fiyatı"]
          .sort_index())
    if len(ts) < 24:  # yetersiz veri varsa atla
        continue

    # b) SARIMAX’i 2019–2022 arasıyla eğit
    train_ts = ts["2019-01-01":"2023-12-31"].asfreq("MS").ffill()
    model = SARIMAX(
        train_ts,
        order=(1,0,10),
        seasonal_order=(0,0,1,12),
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res = model.fit(method='nm', maxiter=200, disp=False)


    # c) Bu grup içindeki test tarihlerdisp024) ve id’lerini al
    sub = grp[grp["tarih"].dt.year == 2024][["id","tarih"]].copy()
    sub = sub.set_index("tarih").sort_index()

    # d) Aylık frekanslı index oluştur
    sub = sub.asfreq("MS")

    # e) Tahminleri al
    sub["ürün fiyatı"] = res.predict(
        start=sub.index[0],
        end=sub.index[-1]
    ).values

    # f) id ve predicted_price’ı topla
    predictions.append(sub[["id","ürün fiyatı"]])

# 5. Tüm grupları birleştir ve submission formatı oluştur
submission = pd.concat(predictions).reset_index(drop=True)

# 6. İstenirse id’ye göre sırala ve ürün fiyatını yuvarla
submission = submission.sort_values(by="id").reset_index(drop=True)
submission["ürün fiyatı"] = submission["ürün fiyatı"].round(2)

# 7. İstenirse CSV’ye yaz
submission.to_csv("submission.csv", index=False)
print("submission.csv oluşturuldu. İlk birkaç satır:")
print(submission.head())
# Out:
# submission.csv oluşturuldu. İlk birkaç satır:
#    id  ürün fiyatı
# 0   0       138.37
# 1   1        45.05
# 2   2        52.82
# 3   3        32.02
# 4   4        54.57
